# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = {'date': ['2014-05-01 18:47:00', '2014-05-01 18:48:00', 
                 '2014-05-01 18:49:00', '2014-05-01 18:50:00', 
                '2014-05-01 18:51:00', '2014-05-01 18:52:00', 
                 '2014-05-01 18:53:00', '2014-05-01 18:54:00',
                 '2014-05-01 18:55:00', '2014-05-01 18:56:00'], 
        'deaths_regiment_1': [34, 43, 14, 15, 15, 14, 31, 25, 62, 41],
        'deaths_regiment_2': [52, 66, 78, 15, 15, 5, 25, 25, 86, 1],
        'deaths_regiment_3': [13, 73, 82, 58, 52, 87, 26, 5, 56, 75],
        'deaths_regiment_4': [44, 75, 26, 15, 15, 14, 54, 25, 24, 72],
        'deaths_regiment_5': [25, 24, 25, 15, 57, 68, 21, 27, 62, 5],
        'deaths_regiment_6': [84, 84, 26, 15, 15, 14, 26, 25, 62, 24],
        'deaths_regiment_7': [46, 57, 26, 15, 15, 14, 26, 25, 62, 41]}
df = pd.DataFrame(data, columns = ['date', 'battle_deaths', 'deaths_regiment_1', 'deaths_regiment_2',
                                   'deaths_regiment_3', 'deaths_regiment_4', 'deaths_regiment_5',
                                   'deaths_regiment_6', 'deaths_regiment_7'])
# df.date = df.date.map(lambda x: pd.to_datetime(x[0:10]))
# df = df.set_index(df.date)
# import numpy as np
df.date = df.date.astype(np.str)

# %%
df.date
# Out:
# 0    2014-05-01 18:47:00
# 1    2014-05-01 18:48:00
# 2    2014-05-01 18:49:00
# 3    2014-05-01 18:50:00
# 4    2014-05-01 18:51:00
# 5    2014-05-01 18:52:00
# 6    2014-05-01 18:53:00
# 7    2014-05-01 18:54:00
# 8    2014-05-01 18:55:00
# 9    2014-05-01 18:56:00
# Name: date, dtype: object

# %%
sns.tsplot([df.deaths_regiment_1, df.deaths_regiment_2, ], color="indianred")

# %%
plt.plot(pd.to_datetime(df.date), df.deaths_regiment_1)

plt.fill_between(pd.to_datetime(df.date),  df.deaths_regiment_1 - 2,  df.deaths_regiment_1 + 3)
# plt.xlim(0, 10);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-46af6580983a> in <module>()
#       1 plt.plot(pd.to_datetime(df.date), df.deaths_regiment_1)
#       2
# ----> 3 plt.fill_between(pd.to_datetime(df.date),  df.deaths_regiment_1 - 2,  df.deaths_regiment_1 + 3)
#       4 # plt.xlim(0, 10);
#
# /Users/stellazhao/anaconda/envs/gl-env/lib/python2.7/site-packages/matplotlib/pyplot.pyc in fill_between(x, y1, y2, where, interpolate, step, hold, data, **kwargs)
#    2998         ret = ax.fill_between(x, y1, y2=y2, where=where,
#    2999                               interpolate=interpolate, step=step, data=data,
# -> 3000                               **kwargs)
#    3001     finally:
#    3002         ax._hold = washold
#
# /Users/stellazhao/anaconda/envs/gl-env/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /Users/stellazhao/anaconda/envs/gl-env/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    4776
#    4777         # Convert the arrays so we can work with them
# -> 4778         x = ma.masked_invalid(self.convert_xunits(x))
#    4779         y1 = ma.masked_invalid(self.convert_yunits(y1))
#    4780         y2 = ma.masked_invalid(self.convert_yunits(y2))
#
# /Users/stellazhao/anaconda/envs/gl-env/lib/python2.7/site-packages/numpy/ma/core.pyc in masked_invalid(a, copy)
#    2360         cls = type(a)
#    2361     else:
# -> 2362         condition = ~(np.isfinite(a))
#    2363         cls = MaskedArray
#    2364     result = a.view(cls)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
